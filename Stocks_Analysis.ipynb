# %% [markdown]
# <a href="https://colab.research.google.com/github/abs711/StocksAnalysis/blob/main/Stocks_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/kaggle_stock_market_dataset'
apple = pd.read_csv(path+'/AAPL.csv')
microsoft = pd.read_csv(path+'/MSFT.csv')
nvidia = pd.read_csv(path+'/NVDA.csv')
amazon = pd.read_csv(path+'/AMZN.csv')
tsmc = pd.read_csv(path+'/TSM.csv')
nuro= pd.read_csv(path+'/NURO.csv')
tsla= pd.read_csv(path+'/TSLA.csv')

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400

# %%
dfs = [apple, microsoft, nvidia, amazon, tsmc, nuro, tsla]

# %% [markdown]
# Add moving averages of closing prices to dfs

# %%
for df in dfs:
  df['ma50'] = df.Close.rolling(50).mean()
  df['ma100'] = df.Close.rolling(100).mean()

# %%
apple.head(50)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1   1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2   1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3   1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4   1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
# 5   1980-12-19  0.504464  0.506696  0.504464  0.504464   0.399707   12157600
# 6   1980-12-22  0.529018  0.531250  0.529018  0.529018   0.419162    9340800
# 7   1980-12-23  0.551339  0.553571  0.551339  0.551339   0.436848   11737600
# 8   1980-12-24  0.580357  0.582589  0.580357  0.580357   0.459840   12000800
# 9   1980-12-26  0.633929  0.636161  0.633929  0.633929   0.502287   13893600
# 10  1980-12-29  0.642857  0.645089  0.642857  0.642857   0.509361   23290400
# ...

# %% [markdown]
# Add previous day closing price

# %%
for df in dfs:
  df['Previous day close price'] = df.Close.shift(1)

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    ma50  ma100  Previous day close price
# 0   NaN    NaN                       NaN
# 1   NaN    NaN                  0.513393
# 2   NaN    NaN                  0.486607
# 3   NaN    NaN                  0.450893
# 4   NaN    NaN                  0.462054

# %% [markdown]
# Add daily changes in prices

# %%
for df in dfs:
  df['Change in price'] = df['Close']- df['Previous day close price']

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    ma50  ma100  Previous day close price  Change in price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
# 4   NaN    NaN                  0.462054         0.013393
#
#    Percent change in price
# 0                      NaN
# 1                -0.052174
# 2                -0.073394
# 3                 0.024752
# ...

# %% [markdown]
# Add percent change in prices

# %%
for df in dfs:
  df['Percent change in price'] = df.Close.pct_change()

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    ma50  ma100  Previous day close price  Change in price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
# 4   NaN    NaN                  0.462054         0.013393
#
#    Percent change in price
# 0                      NaN
# 1                -0.052174
# 2                -0.073394
# 3                 0.024752
# ...

# %% [markdown]
# Add previous day volume snd daily change in volume

# %%
for df in dfs:
    df['Previous day volume'] = df.Volume.shift(1)

    df['Change in volume'] = df['Volume'] - df['Previous day volume']

    df['Percent change in volume'] = df.Volume.pct_change()

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    ma50  ma100  Previous day close price  Change in price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
# 4   NaN    NaN                  0.462054         0.013393
#
#    Percent change in price  Previous day volume  Change in volume  \
# 0                      NaN                  NaN               NaN
# ...

# %% [markdown]
# Add dataframes to csv files

# %%
apple.to_csv(path+'/apple.csv')
microsoft.to_csv(path+'/microsoft.csv')
nvidia.to_csv(path+'/nvidia.csv')
amazon.to_csv(path+'/amazon.csv')
tsmc.to_csv(path+'/tsmc.csv')
nuro.to_csv(path+'/nuro.csv')
tsla.to_csv(path+'/tesla.csv')
